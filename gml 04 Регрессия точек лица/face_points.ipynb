# %%
import skimage.io
import numpy as np

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

# %%
train_labels = pd.read_csv('public_data/00_input/train/gt.csv', index_col='filename')

# %%
images = [skimage.io.imread('public_data/00_input/train/images/{}'.format(i)) 
          for i in os.listdir('public_data/00_input/train/images/')]

# %%
os.listdir('public_data/00_input/train/images/')
# Out:
# ['04354.jpg',
#  '02725.jpg',
#  '00132.jpg',
#  '00654.jpg',
#  '02043.jpg',
#  '04432.jpg',
#  '02057.jpg',
#  '05738.jpg',
#  '04426.jpg',
#  '03349.jpg',
#  '00640.jpg',
#  '00898.jpg',
#  '01238.jpg',
#  '00126.jpg',
#  '04340.jpg',
#  '02731.jpg',
#  '01210.jpg',
#  '03407.jpg',
#  '04368.jpg',
#  '05076.jpg',
#  '02719.jpg',
#  '05710.jpg',
#  '03361.jpg',
#  '00668.jpg',
#  '01576.jpg',
#  '01562.jpg',
#  '05704.jpg',
#  '03375.jpg',
#  '03413.jpg',
#  '05062.jpg',
#  '01204.jpg',
#  '05089.jpg',
#  '04397.jpg',
#  '05937.jpg',
#  '02080.jpg',
#  '01589.jpg',
#  '00697.jpg',
#  '00683.jpg',
#  '05923.jpg',
#  '02094.jpg',
#  '04383.jpg',
#  '02902.jpg',
#  '00873.jpg',
#  '00867.jpg',
#  '02916.jpg',
#  '04630.jpg',
#  '02241.jpg',
#  '01748.jpg',
#  '01990.jpg',
#  '00456.jpg',
#  '00330.jpg',
#  '02527.jpg',
#  '05248.jpg',
#  '04156.jpg',
#  '03639.jpg',
#  '02533.jpg',
#  '04142.jpg',
#  '00324.jpg',
#  '01984.jpg',
#  '00442.jpg',
#  '04624.jpg',
#  '02255.jpg',
# ...

# %%
plt.imshow(images[1])

# %%
train_labels.index[0]
# Out:
# '00000.jpg'

# %%
train_labels.loc['00001.jpg']
# Out:
# x1     21
# y1     20
# x2     36
# y2     18
# x3     57
# y3     19
# x4     80
# y4     25
# x5     23
# y5     27
# x6     34
# y6     26
# x7     40
# y7     28
# x8     59
# y8     30
# x9     68
# y9     30
# x10    78
# y10    33
# x11    43
# y11    46
# x12    31
# y12    61
# x13    45
# y13    66
# x14    60
# y14    65
# Name: 00001.jpg, dtype: int64
